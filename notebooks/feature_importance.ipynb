# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

feature_importance = pd.read_csv("../perm_importance.csv")
feature_importance.columns = ['m', 'features', 'importance']

# feature_importance['features'] = feature_importance['features'].str.extract(r'(\w+)_')
# feature_importance = feature_importance.groupby('features')['importance'].sum().reset_index()

sorted_importance = feature_importance.sort_values(by='importance', ascending=False)
print(sorted_importance.iloc[:, -2:])
# Out:
#               features  importance
# 7                  idw     0.45008
# 6          global_temp     0.18519
# 3         geomorhpon_c     0.00033
# 8              laplace     0.00004
# 0      bare_earth_freq     0.00001
# 9                 ndvi     0.00001
# 10             ndvistd     0.00001
# 1                 dist     0.00000
# 2      esri_lulc2020_c     0.00000
# 4   gl_surface_water_c     0.00000
# 5       global_crops_c     0.00000
# 11  world_settlement_c     0.00000

# %%
plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_importance)), sorted_importance['importance'], align='center')
plt.yticks(range(len(sorted_importance)), sorted_importance['features'])
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance Plot')
plt.show()

# %%
plt.barh(y = np.arange(len(feature_importance)), width=feature_importance)

plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Feature Importance Bar Chart')
plt.show()


# forest_importances = pd.Series(importances, index=feature_names)

# fig, ax = plt.subplots()
# forest_importances.plot.bar(yerr=std, ax=ax)
# ax.set_title("Feature importances using MDI")
# ax.set_ylabel("Mean decrease in impurity")
# fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.barh(y = np.arange(len(feature_importance)), width=feature_importance)
#       3 plt.xlabel('Feature Importance')
#       4 plt.ylabel('Feature')
#
# File ~/opt/miniconda3/envs/RFterrain/lib/python3.11/site-packages/matplotlib/pyplot.py:2457, in barh(y, width, height, left, align, data, **kwargs)
#    2453 @_copy_docstring_and_deprecators(Axes.barh)
#    2454 def barh(
#    2455         y, width, height=0.8, left=None, *, align='center',
#    2456         data=None, **kwargs):
# -> 2457     return gca().barh(
#    2458         y, width, height=height, left=left, align=align,
#    2459         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
